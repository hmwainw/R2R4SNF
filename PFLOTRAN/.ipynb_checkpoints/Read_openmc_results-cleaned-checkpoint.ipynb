# %%
# Import the python modules and openmc modules 
# %matplotlib inline
import openmc
import openmc.deplete
import math
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Path to the decay chain file used for the simulation
openmc.config['chain_file']='./nuclear_data/chain_endfb71_pwr.xml'

# %% [markdown]
# ## Functions

# %%
# Read and return the results from the depletion simulation for one reactor
def get_results(reactor, primary_path):
    ## ---- Parameters: 
    # reactor (str) - reactor name
    # primary_path (str) - a path to the directory in which openmc files are stored
    ## ---- Returns: 
    # results - openmc depletion calculation results
    
    results_file = primary_path+ "depletion_results.h5" # path to the depletion_results.h5 file
    results      = openmc.deplete.Results(results_file)
    
    return results

# %%
# Read the result file and create a list with [time (d), keff, k uncerntainty, discharge step] 
def get_crit_param(results):
    ## ---- Parameters: 
    #  results - openmc depletion calculation results
    ## ---- Returns: 
    #  crit_param (tuple) - the criticality prameters including:
    #    - time - time in years
    #    - keff - k-effective as a function of time
    #    - discharge - discharge time step
    
    time, k     = results.get_keff()
    keff        = k[:,0]
    n_discharge = np.max(np.nonzero(keff))
    crit_param  = (time/(24*60*60), keff, n_discharge)
    
    return crit_param

# %%
# Return the last value of keff
def get_keff_final(crit_param):
    ## ---- Parameters: 
    #  crit_param (tuple) - the result from get_crit_param(results)
    ## ---- Returns: 
    #  keff_final including
    #  time[n] - the time of discharge
    #  keff[n] - k_eff at the time of discharge
    
    n_discharge = crit_param[2]
    time        = crit_param[0]
    keff        = crit_param[1]

    keff_final  = (time[n_discharge],keff[n_discharge])
    
    return keff_final

# %%
# Return the number of steps of the enire simulation
def number_steps(crit_param):
    ## ---- Parameters: 
    #  crit_param (tuple) - the result from get_crit_param(results)
    #  reactor(str) - reactor name
    ## ---- Returns: 
    #  n - the number of time steps
    
    time  = crit_param[0]
    n_tot = len(time)
    
    return n_tot

# %%
# Convert the output data (activity, decay heat...) from /gHM to /GWe.y
def conv_GWe_y(value, reactor): # value should be given in value/gHM
    ## ---- Parameters: 
    #  value - the value to be converted to per electricity production
    #  reactor(str) - reactor name
    ## ---- Returns: 
    #  value per electricity production
    
    param = get_parameters(reactor)
    
    return value*365/(param[2]*param[1]*(10**-6))

# %% [markdown]
# Radionucide Composition of SNF

# %%
# Create a collection of OpenMC Material with the spent fuel material at each stage
## crit_param is a list containing [time, keff, kun, discharge step]
## id_mat correspond to the ID of the depleted material (usually '1' for the fuel)
def get_snf_composition(primary_path, results, crit_param, id_mat):
    ## ---- Parameters: 
    #  primary_path (str) - a path to the directory in which openmc files are stored
    #  results - openmc depletion calculation results
    #  crit_param (tuple) - the result from get_crit_param(results)
    #  id_mat - the ID of the depleted material (usually '1' for the fuel)
    ## ---- Returns: 
    #  snf_composition - a collection of OpenMC Material with the spent fuel material at each time step
    
    n_tot           = number_steps(crit_param)
    snf_composition = [results.export_to_materials(burnup_index=i,path=primary_path+ 'materials.xml')[int(id_mat)-1] for i in range(n_tot) ]# burnup index= step number, path=path to the materials.xml file use for the simulation

    return snf_composition

# %% [markdown]
# Burnup at each time steps

# %%
# Return a list with the value of the input power during operation and discharge
def get_power(param, crit_param):
    ## ---- Parameters: 
    #  param - reactor parameters
    #  crit_param (tuple) - the result from get_crit_param(results)
    ## ---- Returns: 
    #  power - total power out during operation and after discharge
    
    n_discharge = crit_param[2] # discharge step
    n_tot       = number_steps(crit_param) # total time step
    
    power   = [param[0] for i in range(n_discharge+1)]
    cooling = [0 for i in range(n_tot - n_discharge-1)]
    power   = power+cooling
    
    return power

# %%
# Return a list with the value of the burnup at each time step
def get_burnup(power, snf_composition, crit_param): # time must be given in days
    ## ---- Parameters: 
    #  power - total power out during operation and after discharge from power_evolution()  
    #  crit_param (tuple) - the result from get_crit_param(results)
    #  snf_composition - a collection of OpenMC Material with the spent nuclear fuel material composition at each time step
    ## ---- Returns: 
    #  burnup_step - burnup at each time step
       
    fis_mass = snf_composition[0].fissionable_mass  
    time     = crit_param[0]
    
    burnup =[time[i]*power[i]/((10**3)*fis_mass) for i in range(len(time))]
    
    return burnup

# %% [markdown]
# Activity of the spent fuel

# %%
# Create a dataframe with the activity of the spent fuel at each time step, for each nuclide
## material collec is the collection of materials obtained with material_collection
def get_activity(snf_composition, crit_param):
    ## ---- Parameters: 
    #  snf_composition - a collection of OpenMC Material with the spent fuel material at each time step
    #  crit_param (tuple) - the result from crit_param(results)
    ## ---- Returns: 
    #  df_snf - dataframe containing the activity of each radionuclide in SNF at each time step
    
    n_tot = number_steps(crit_param)    
    time  = crit_param[0]
    
    df_act = pd.DataFrame()
    for i in range (n_tot):
        act       = snf_composition[i].get_activity(by_nuclide=True, units='Bq/g')
        df_act[i] = pd.DataFrame.from_dict(act, orient='index', columns=[i])
    
    df_act.columns=time
    
    return df_act

# %%
# Create a dataframe with the total activity(Bq/g) of the spent fuel at each time step
def get_activity_tot(snf_composition, crit_param): 
    ## ---- Parameters: 
    #  snf_composition - a collection of OpenMC Material with the spent fuel material at each time step
    #  crit_param (tuple) - the result from get_crit_param(results)
    ## ---- Returns: 
    #  df_act - dataframe containing the total activity(Bq/g) of the spent fuel at each time step

    n_tot = number_steps(crit_param)    
    time  = crit_param[0]
    
    act_tot = [snf_composition[i].get_activity(by_nuclide=False, units='Bq/g') for i in range(n_tot)]
    df_act  = pd.DataFrame(act_tot, index=time, columns=['Total_Activity (Bq/g)'])
    
    return df_act

# %% [markdown]
# Decay heat of the spent fuel

# %%
# Create a dataframe with the decay heat of the spent fuel fro at each time step
def get_decay_heat(snf_composition, crit_param):
    ## ---- Parameters: 
    #  snf_composition - a collection of OpenMC Material with the spent fuel material at each time step
    #  crit_param (tuple) - the result from get_crit_param(results)
    ## ---- Returns: 
    #  df_DH - dataframe containing the decay heat (W/g) of the spent fuel at each time step

    n_tot = number_steps(crit_param)    
    time  = crit_param[0]
    
    df_DH = pd.DataFrame()
    for i in range(n_tot):
        DH       = snf_composition[i].get_decay_heat(units= 'W/g', by_nuclide=True)
        df_DH[i] = pd.DataFrame.from_dict(DH, orient='index', columns=[i])
        
    
    df_DH.columns=time
    
    return df_DH

# %%
# Create a dataframe with the total decay heat of the spent fuel at each time step
def get_decay_heat_tot(snf_composition, crit_param):
    ## ---- Parameters: 
    #  snf_composition - a collection of OpenMC Material with the spent fuel material at each time step
    #  crit_param (tuple) - the result from get_crit_param(results)
    ## ---- Returns: 
    #  df_DH - dataframe containing the total decay heat (W/g) of the spent fuel at each time step
    n_tot = number_steps(crit_param)    
    time  = crit_param[0]
    
    DH_tot     = [snf_composition[i].get_decay_heat(units='W/g',by_nuclide=False) for i in range(n_tot)]
    df_DH_tot  = pd.DataFrame(DH_tot, index=time, columns=['Total_Decay_Heat (W/g)'])
    
    return df_DH_tot

# %% [markdown]
# Radiotoxicity

# %%
# Return the radiotoxicity for each nuclide
def get_toxicity(snf_composition, crit_param):
    ## ---- Parameters: 
    #  snf_composition - a collection of OpenMC Material with the spent fuel material at each time step
    #  crit_param (tuple) - the result from get_crit_param(results)
    ## ---- Returns: 
    #  df_tox - dataframe containing the radiotoxicity for each nuclide at each time step
    
    # Path to the CSV file containing the DCF/ MPC factors 
    df_DCF = pd.read_csv('DCF_ingestion.csv', sep=';')
    df_DCF.set_index('Isotope', inplace=True) # Custom the dataframe
    df_DCF = df_DCF.iloc[1:,:].dropna()

    df_tox_mat = get_activity(snf_composition, crit_param) # dataframe containing the activity of each nuclide
    df_tox = df_tox_mat.merge(df_DCF, left_index=True, right_index=True, how='inner') # merge the 2 dataframe
    df_tox = df_tox.mul(df_tox['Conversion factors (Sv/Bq)'], axis='index') # multiply the activity by the dose conversion factor for each nuclide
    df_tox = df_tox.iloc[:, :-1]
    
    return df_tox

# %%
# Return the total radiotoxicity for each time step
def get_toxicity_tot(snf_composition, crit_param):
    ## ---- Parameters: 
    #  snf_composition - a collection of OpenMC Material with the spent fuel material at each time step
    #  crit_param (tuple) - the result from get_crit_param(results)
    ## ---- Returns: 
    #  df_tox_tot - dataframe containing the total radiotoxicity at each time step
       
    time  = crit_param[0]
    
    df_tox = get_toxicity(snf_composition, crit_param)
    df_tox_tot = df_tox.sum(axis=0)
    df_tox_tot = df_tox_tot.transpose()
    df_tox_tot = df_tox_tot.set_axis(time)
    
    return df_tox_tot

# %% [markdown]
# SNF Mass and Volume

# %%
# Return SNF mass kg/MWe.year
def get_SNF_mass(param): 
    ## ---- Parameters: 
    #  param - reactor parameters 
    ## ---- Returns: 
    #  snf_mass - dataframe containing the total decay heat (W/g) of the spent fuel at each time step
    
    burnup_discharge = param[2]
    efficiency       = param[1]
    snf_mass         = 365/(burnup_discharge*efficiency)
    
    return snf_mass

# %%
# Return the SNF volume in m3/ GWe.year
def get_SNF_volume(param, snf_composition):
    ## ---- Parameters: 
    #  snf_composition - a collection of OpenMC Material with the spent fuel material at each time step
    #  param - reactor parameters 
    ## ---- Returns: 
    #  snf_volume = dataframe containing the total decay heat (W/g) of the spent fuel at each time step   
    
    volume_model = param[3]
    
    fiss_mass = snf_composition[0].fissionable_mass

    snf_mass   = get_SNF_mass(param)
    snf_volume = volume_model*snf_mass/fiss_mass
       
    return snf_volume

# %% [markdown]
# I129 concentration

# %%
# Calculate I129 concentration in atom/cm3
def get_I129(results):
    ## ---- Parameters: 
    #  results - openmc depletion calculation results
    ## ---- Returns: 
    #  I129 - I129 concentration in atom/cm3
    
    _, I129 = results.get_atoms("1", "I129", nuc_units='atom/cm3', time_units='d')
    
    return I129

# %% [markdown]
# ## Dataframe with all the results

# %%
# Return a dataframe containing the main metrics and parameters useful in the study
def global_df(reactor, results):
    df = pd.DataFrame()
    
    # Previous results
    param      = get_parameters(reactor)
    crit_param = get_crit_param(results)
    
    snf_composition = get_snf_composition(primary_path, results, crit_param, "1")
    
    n     = number_steps(crit_param)
    power = get_power(param, crit_param)
    
    # Gather the information for the dataframe 
    df['keff'] = crit_param[1]
    df.set_index(crit_param[0], inplace=True)
    df['burnup'] = get_burnup(power, snf_composition, crit_param)
    df['Power (W/cm)'] = power
    df['Activity (Bq/g)'] = get_activity_tot(snf_composition, crit_param)
    df['Activity (Ci/GWe.y)'] = conv_GWe_y(df['Activity (Bq/g)'], reactor)*27*(10**-12)
    df['Decay heat (W/g)']=get_decay_heat_tot(snf_composition, crit_param)
    df['Decay heat (W/GWe.y)'] = conv_GWe_y(df['Decay heat (W/g)'], reactor)
    df['Radiotoxicity (Sv/g)'] = get_toxicity_tot(snf_composition, crit_param)
    df['Radiotoxicity (Sv/GWe.y)'] = conv_GWe_y(df['Radiotoxicity (Sv/g)'], reactor)
    df['I129 (atom/cm3)'] = get_I129(results)
    df['I129 (atom/GWe.y)'] = df['I129 (atom/cm3)']*snf_composition[0].volume*365/(param[0]*get_keff_final(crit_param)[0]*param[1])*(10**9)
    df['Efficiency']=param[1]
    df['Volume Model (cm3)'] = param[3]
    df['SNF mass (t/GWe.y)'] = get_SNF_mass(param)
    df['SNF volume (m3/(GWe.y))'] = get_SNF_volume(param, snf_composition)
    df['discharge step'] = crit_param[2]
    df['discharge time'] = get_keff_final(crit_param)[0]
    df['volume_Ueq']= snf_composition[0].volume
    df['mass U'] = snf_composition[0].fissionable_mass
    return df

# %%
# Return an array of dataframes with the activity, radiotoxicity, decay heat per nuclide at each time step
# Make the comparison with detailed composition easier
def by_nuclide(reactor, results):
    # Gather the parameters for the reactor
    param = get_parameters(reactor)
    crit_param = get_crit_param(results)
    snf_composition = get_snf_composition(primary_path, results, crit_param, "1")
    n_tot =number_steps(crit_param)
    time = crit_param[0] # time steps
    n_discharge = crit_param[2] # the time steps of the discharge step
    
    # Create the dataframe
    df_act = get_activity(snf_composition, crit_param) # activity
    df_DH  = get_decay_heat(snf_composition, crit_param) #decay heat
    df_tox = get_toxicity(snf_composition, crit_param) # radiotoxicity
    #Same dataframe in /GWe.y
    df_act_conv = conv_GWe_y(df_act, reactor)
    df_DH_conv  = conv_GWe_y(df_DH, reactor)
    df_tox_conv = conv_GWe_y(df_tox, reactor)
    return (df_act, df_DH, df_tox,time, n_discharge, df_act_conv, df_DH_conv, df_tox_conv)

# %%
# Create 2 csv files with the df_global dataframe
def df_to_csv(reactor,primary_path):
    results     = get_results(reactor, primary_path)
    df          = global_df(reactor, results) # dataframe containing the results for operation + discharge time 
    n_discharge = df['discharge step'][0]
    df_cooling  = df.iloc[n_discharge:].copy(deep=True) # dataframe containing the value only after discharge from the reactor
    df.to_csv(path_or_buf=primary_path+'out_'+reactor+'.csv', index=True, header=True)
    df_cooling.to_csv(path_or_buf=primary_path+'cooling'+reactor+'.csv', index=True, header=True)

# %%
# Return a dataframe containing the contribution of each nuclide for the metric consider, contained in df
def df_prop(df):
    total = df.sum(axis=0)
    df_prop=df/total
    return df_prop

# %%
def by_nuclide_csv(reactor, primary_path):
    results = get_results(reactor, primary_path)
    # Dataframe with the waste management metrics by nuclide    
    df_act, df_DH, df_tox, time, tis_dis, df_act_conv, df_DH_conv, df_tox_conv=by_nuclide(reactor, results)
    
    # For each metrics, calculate the contribution of each metric
    act_prop=df_prop(df_act)
    DH_prop=df_prop(df_DH)
    tox_prop=df_prop(df_tox)
        
    # Dataframe to export to csv for analysis    
    df_act.to_csv(path_or_buf=primary_path+'activity_'+reactor+'.csv', index=True, header=True)
    df_DH.to_csv(path_or_buf=primary_path+'decay_heat_'+reactor+'.csv', index=True, header=True)
    df_tox.to_csv(path_or_buf=primary_path+'radiotoxicity_'+reactor+'.csv', index=True, header=True)
    df_act_conv.to_csv(path_or_buf=primary_path+'activity_conv_'+reactor+'.csv', index=True, header=True)
    df_DH_conv.to_csv(path_or_buf=primary_path+'decay_heat_conv_'+reactor+'.csv', index=True, header=True)
    df_tox_conv.to_csv(path_or_buf=primary_path+'radiotoxicity_conv_'+reactor+'.csv', index=True, header=True)
    act_prop.to_csv(path_or_buf=primary_path+'activity_prop_'+reactor+'.csv', index=True, header=True)
    DH_prop.to_csv(path_or_buf=primary_path+'decay_heat_prop_'+reactor+'.csv', index=True, header=True)
    tox_prop.to_csv(path_or_buf=primary_path+'radiotoxicity_prop_'+reactor+'.csv', index=True, header=True)

# %% [markdown]
# ## Example

# %% [markdown]
# ## Single reactor

# %% [markdown]
# Set-up

# %%
# List of the reactors name to study 
reactor = 'SFR'
primary_path='Results/'+reactor+'/'

# Necessary files
# rimary_path+ "depletion_results.h5" - openMC output file
# DCF_ingestion.csv - the DCF/ MPC factors in the running directory 
# primary_path+ 'materials.xml' - openMC material file 

# Need to change the path
#/Users/harukowainwright/Documents/Projects/Chloe/Codes/nuclear_data/materials.xml

def get_parameters(reactor): 
# Return the input parameters of the simulations [linear power (W/cm), thermal efficiency, discharge burnup, volume_model]
    if (reactor=='eVinci'):
        parameters=[76969.02001294993, 0.33, 80, np.pi*(70**2) ]
    if (reactor=='HTGR_60'):
        parameters=[76969.02001294993, 0.50, 60, np.pi*(70**2) ]
    if (reactor=='HTGR_40'):
        parameters=[76969.02001294993, 0.50, 40, np.pi*(70**2) ]
    if (reactor=='HTGR_20'):
        parameters=[76969.02001294993, 0.50, 20, np.pi*(70**2) ]
    if (reactor=='HTGR_80'):
        parameters=[76969.02001294993, 0.50, 80, np.pi*(70**2) ]
    if (reactor=='HTGR_100'):
        parameters=[76969.02001294993, 0.50, 100, np.pi*(70**2) ]
    if (reactor=='USNC'):
        parameters=[190066.35554218251, 0.33, 80, np.pi*(110**2) ]
    if (reactor=='Ref_PWR'):
        parameters=[5.72*1000*1.26/30.48, 0.33, 50, (np.pi*(119.7*2.54/2)**2)/(157*264)*1.26]
        # the volume is (cladding outer radius)^2*pi*(pitch)
    if (reactor=='Micro_PWR'):
        parameters=[3.90*1000*1.26/30.48, 0.33, 15, (np.pi*(4.94*30.48/2)**2)/(37*264)*1.26]
        # the volume is (cladding outer radius)^2*pi*(pitch)
    if (reactor=='SFR'):
        parameters=[250000, 0.4, 120, 3179.8823521410927]
    return parameters

# %% [markdown]
# Run codes

# %%
# Create csv file containing the results and main parameters
df_to_csv(reactor, primary_path)
# Out:
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=1.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=2.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=3.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=6.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=7.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=8.
#   warn(msg, IDWarning)
# /var/folders/53/mywvp84j3zv5w72jr7dh8jth0000gn/T/ipykernel_69209/1670633048.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_act[i] = pd.DataFrame.from_dict(act, orient='index', columns=[i])

# %%
# Create csv files detailed per nuclide for each reactor
by_nuclide_csv(reactor, primary_path)
# Out:
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=1.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=2.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=3.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=6.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=7.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=8.
#   warn(msg, IDWarning)
# /var/folders/53/mywvp84j3zv5w72jr7dh8jth0000gn/T/ipykernel_69209/1670633048.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_act[i] = pd.DataFrame.from_dict(act, orient='index', columns=[i])
# /var/folders/53/mywvp84j3zv5w72jr7dh8jth0000gn/T/ipykernel_69209/2074422332.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_DH[i] = pd.DataFrame.from_dict(DH, orient='index', columns=[i])
# /var/folders/53/mywvp84j3zv5w72jr7dh8jth0000gn/T/ipykernel_69209/1670633048.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_act[i] = pd.DataFrame.from_dict(act, orient='index', columns=[i])

# %% [markdown]
# ## Multiple reactors

# %%
reactors=['Ref_PWR', 'Micro_PWR', 'HTGR_80', 'eVinci', 'USNC','SFR']

for reactor in reactors:
    primary_path='Results/'+reactor+'/'
    df_to_csv(reactor, primary_path)
# Out:
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=1.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=2.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=3.
#   warn(msg, IDWarning)
# /var/folders/53/mywvp84j3zv5w72jr7dh8jth0000gn/T/ipykernel_69209/2602350219.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_act[i] = pd.DataFrame.from_dict(act, orient='index', columns=[i])
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=1.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=2.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=3.
#   warn(msg, IDWarning)
# /var/folders/53/mywvp84j3zv5w72jr7dh8jth0000gn/T/ipykernel_69209/2602350219.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_act[i] = pd.DataFrame.from_dict(act, orient='index', columns=[i])
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=1.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=2.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=3.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=4.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=5.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=6.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=8.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=9.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=10.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=11.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=12.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=14.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=15.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=16.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=17.
#   warn(msg, IDWarning)
# /var/folders/53/mywvp84j3zv5w72jr7dh8jth0000gn/T/ipykernel_69209/2602350219.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_act[i] = pd.DataFrame.from_dict(act, orient='index', columns=[i])
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=1.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=2.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=3.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=4.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=5.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=6.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=8.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=9.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=10.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=11.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=12.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=14.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=15.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=16.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=17.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=18.
#   warn(msg, IDWarning)
# /var/folders/53/mywvp84j3zv5w72jr7dh8jth0000gn/T/ipykernel_69209/2602350219.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_act[i] = pd.DataFrame.from_dict(act, orient='index', columns=[i])
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=1.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=2.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=3.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=4.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=5.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=6.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=8.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=14.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=15.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=16.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=17.
#   warn(msg, IDWarning)
# /var/folders/53/mywvp84j3zv5w72jr7dh8jth0000gn/T/ipykernel_69209/2602350219.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_act[i] = pd.DataFrame.from_dict(act, orient='index', columns=[i])
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=1.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=2.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=3.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=6.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=8.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=7.
#   warn(msg, IDWarning)
# /var/folders/53/mywvp84j3zv5w72jr7dh8jth0000gn/T/ipykernel_69209/2602350219.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_act[i] = pd.DataFrame.from_dict(act, orient='index', columns=[i])

# %%
for reactor in reactors:
    primary_path='Results/'+reactor+'/'
    by_nuclide_csv(reactor,primary_path)
# Out:
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=1.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=2.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=3.
#   warn(msg, IDWarning)
# /var/folders/53/mywvp84j3zv5w72jr7dh8jth0000gn/T/ipykernel_69209/2602350219.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_act[i] = pd.DataFrame.from_dict(act, orient='index', columns=[i])
# /var/folders/53/mywvp84j3zv5w72jr7dh8jth0000gn/T/ipykernel_69209/1611469540.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_DH[i] = pd.DataFrame.from_dict(act, orient='index', columns=[i])
# /var/folders/53/mywvp84j3zv5w72jr7dh8jth0000gn/T/ipykernel_69209/2602350219.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_act[i] = pd.DataFrame.from_dict(act, orient='index', columns=[i])
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=1.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=2.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=3.
#   warn(msg, IDWarning)
# /var/folders/53/mywvp84j3zv5w72jr7dh8jth0000gn/T/ipykernel_69209/2602350219.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_act[i] = pd.DataFrame.from_dict(act, orient='index', columns=[i])
# /var/folders/53/mywvp84j3zv5w72jr7dh8jth0000gn/T/ipykernel_69209/1611469540.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_DH[i] = pd.DataFrame.from_dict(act, orient='index', columns=[i])
# /var/folders/53/mywvp84j3zv5w72jr7dh8jth0000gn/T/ipykernel_69209/2602350219.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_act[i] = pd.DataFrame.from_dict(act, orient='index', columns=[i])
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=1.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=2.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=3.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=4.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=5.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=6.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=8.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=9.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=10.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=11.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=12.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=14.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=15.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=16.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=17.
#   warn(msg, IDWarning)
# /var/folders/53/mywvp84j3zv5w72jr7dh8jth0000gn/T/ipykernel_69209/2602350219.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_act[i] = pd.DataFrame.from_dict(act, orient='index', columns=[i])
# /var/folders/53/mywvp84j3zv5w72jr7dh8jth0000gn/T/ipykernel_69209/1611469540.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_DH[i] = pd.DataFrame.from_dict(act, orient='index', columns=[i])
# /var/folders/53/mywvp84j3zv5w72jr7dh8jth0000gn/T/ipykernel_69209/2602350219.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_act[i] = pd.DataFrame.from_dict(act, orient='index', columns=[i])
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=1.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=2.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=3.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=4.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=5.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=6.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=8.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=9.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=10.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=11.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=12.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=14.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=15.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=16.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=17.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=18.
#   warn(msg, IDWarning)
# /var/folders/53/mywvp84j3zv5w72jr7dh8jth0000gn/T/ipykernel_69209/2602350219.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_act[i] = pd.DataFrame.from_dict(act, orient='index', columns=[i])
# /var/folders/53/mywvp84j3zv5w72jr7dh8jth0000gn/T/ipykernel_69209/1611469540.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_DH[i] = pd.DataFrame.from_dict(act, orient='index', columns=[i])
# /var/folders/53/mywvp84j3zv5w72jr7dh8jth0000gn/T/ipykernel_69209/2602350219.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_act[i] = pd.DataFrame.from_dict(act, orient='index', columns=[i])
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=1.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=2.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=3.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=4.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=5.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=6.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=8.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=14.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=15.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=16.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=17.
#   warn(msg, IDWarning)
# /var/folders/53/mywvp84j3zv5w72jr7dh8jth0000gn/T/ipykernel_69209/2602350219.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_act[i] = pd.DataFrame.from_dict(act, orient='index', columns=[i])
# /var/folders/53/mywvp84j3zv5w72jr7dh8jth0000gn/T/ipykernel_69209/1611469540.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_DH[i] = pd.DataFrame.from_dict(act, orient='index', columns=[i])
# /var/folders/53/mywvp84j3zv5w72jr7dh8jth0000gn/T/ipykernel_69209/2602350219.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_act[i] = pd.DataFrame.from_dict(act, orient='index', columns=[i])
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=1.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=2.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=3.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=6.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=7.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=8.
#   warn(msg, IDWarning)
# /var/folders/53/mywvp84j3zv5w72jr7dh8jth0000gn/T/ipykernel_69209/2602350219.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_act[i] = pd.DataFrame.from_dict(act, orient='index', columns=[i])
# /var/folders/53/mywvp84j3zv5w72jr7dh8jth0000gn/T/ipykernel_69209/1611469540.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_DH[i] = pd.DataFrame.from_dict(act, orient='index', columns=[i])
# /var/folders/53/mywvp84j3zv5w72jr7dh8jth0000gn/T/ipykernel_69209/2602350219.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_act[i] = pd.DataFrame.from_dict(act, orient='index', columns=[i])

# %%
results = get_results(reactor, primary_path)
crit_param = get_crit_param(results)
snf_composition = get_snf_composition(primary_path, results, crit_param, 1)
# Out:
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=1.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=2.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=3.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=6.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=7.
#   warn(msg, IDWarning)
# /Users/harukowainwright/anaconda3/envs/openmc-env/lib/python3.12/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=8.
#   warn(msg, IDWarning)

# %%
snf_composition[117]['Am242']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[158], line 1
# ----> 1 snf_composition[117]['Am242']
#
# TypeError: 'Material' object is not subscriptable

# %%
n = [118,119,120,121,122]

snf_composition[10]

# %%
act['Am242']
# Out:
# 107922844.60588785

# %%
snf_composition[117]
# Out:
# Material
# 	ID             =	1
# 	Name           =	UPuZr
# 	Temperature    =	None
# 	Density        =	15.8 [sum]
# 	Volume         =	1504.0640578268658 [cm^3]
# 	Depletable     =	True
# 	S(a,b) Tables
# 	Nuclides
# 	Pu238          =	1.4446494601429541e-06 [ao]
# 	Am242          =	6.157522289133904e-08 [ao]
# 	Cm242          =	8.052144531944335e-08 [ao]
# 	Cm244          =	9.473111214052158e-09 [ao]
# 	Ac225          =	2.246307637194221e-13 [ao]
# 	Ac227          =	4.4423041655012834e-11 [ao]
# 	Ag107          =	6.860797610334754e-07 [ao]
# 	Ag109          =	5.8131635798570005e-05 [ao]
# 	Al27           =	9.995919514795721e-22 [ao]
# 	Am241          =	3.86594949495416e-12 [ao]
# 	Am243          =	5.183503504234294e-09 [ao]
# 	Ar36           =	9.826570666807564e-22 [ao]
# 	Ar38           =	9.997754863763399e-22 [ao]
# 	Ar40           =	1.0058880177872604e-21 [ao]
# 	As75           =	5.315079441489108e-08 [ao]
# 	Au197          =	8.869913559534865e-22 [ao]
# 	B10            =	5.125476841025305e-22 [ao]
# 	B11            =	1.0062555774711742e-21 [ao]
# 	Ba130          =	2.355483737654129e-18 [ao]
# 	Ba132          =	2.1792169525838849e-10 [ao]
# 	Ba134          =	1.4705753715803604e-05 [ao]
# 	Ba135          =	5.261124396897071e-06 [ao]
# 	Ba136          =	1.0684550118923821e-05 [ao]
# 	Ba137          =	0.00029562086556039454 [ao]
# 	Ba138          =	0.0002774436687990416 [ao]
# 	Be9            =	1.6665951635370723e-21 [ao]
# 	Bi209          =	1.2196826171357337e-07 [ao]
# 	Bk245          =	7.525459935389798e-77 [ao]
# 	Bk250          =	2.1327461034916053e-30 [ao]
# 	Br79           =	2.0018952429553807e-07 [ao]
# 	Br81           =	7.3904110478586995e-06 [ao]
# 	Ca40           =	9.891671214398471e-22 [ao]
# 	Ca42           =	1.0010864921399903e-21 [ao]
# 	Ca43           =	9.96217630290405e-22 [ao]
# 	Ca44           =	1.0054052787583831e-21 [ao]
# 	Ca46           =	9.995614789640816e-22 [ao]
# 	Ca48           =	9.999026389806587e-22 [ao]
# 	Cd106          =	5.938578251454873e-19 [ao]
# 	Cd108          =	2.2862774911907417e-09 [ao]
# 	Cd110          =	5.001464289535291e-06 [ao]
# 	Cd111          =	1.1741189279357641e-05 [ao]
# 	Cd112          =	6.426666879218872e-06 [ao]
# 	Cd113          =	3.433311130248534e-06 [ao]
# 	Cd114          =	2.8498362510937578e-06 [ao]
# 	Cd116          =	2.188718903449456e-06 [ao]
# 	Ce136          =	8.445956575512282e-21 [ao]
# 	Ce138          =	8.875464330201823e-12 [ao]
# 	Ce140          =	0.000248163939537663 [ao]
# 	Ce142          =	0.00022097951610180246 [ao]
# 	Ce143          =	1.9068347201864335e-25 [ao]
# 	Cf249          =	8.699631733376684e-59 [ao]
# 	Cf250          =	7.622290163047871e-26 [ao]
# 	Cf254          =	9.567913237201654e-39 [ao]
# 	Cl35           =	9.980270845072252e-22 [ao]
# 	Cl37           =	1.0257972344956476e-21 [ao]
# 	Cm241          =	1.7759437763007876e-31 [ao]
# 	Cm243          =	1.6761530313508084e-48 [ao]
# 	Cm245          =	7.197545694606877e-11 [ao]
# 	Cm246          =	1.2061287394803207e-13 [ao]
# 	Cm247          =	3.4690277065103546e-12 [ao]
# 	Cm248          =	5.950580097605182e-14 [ao]
# 	Cm250          =	6.038833486658026e-22 [ao]
# 	Co59           =	1.3750054999351741e-21 [ao]
# 	Cr50           =	9.900105622168494e-22 [ao]
# 	Cr52           =	1.0028520170835917e-21 [ao]
# 	Cr53           =	9.979348234441446e-22 [ao]
# 	Cr54           =	1.0073977738218472e-21 [ao]
# 	Cs133          =	0.00030323094193445956 [ao]
# 	Cs135          =	0.0003303055944051105 [ao]
# 	Cs137          =	4.428205263920516e-23 [ao]
# 	Cu63           =	1.4394141621869955e-15 [ao]
# 	Cu65           =	1.4279841611100287e-13 [ao]
# 	Dy156          =	9.20381666939282e-19 [ao]
# 	Dy158          =	2.0757395768343782e-11 [ao]
# 	Dy160          =	1.5254972277869086e-07 [ao]
# 	Dy161          =	1.893710720191645e-07 [ao]
# 	Dy162          =	1.1384900617872155e-07 [ao]
# 	Dy163          =	3.8263815105064526e-08 [ao]
# 	Dy164          =	1.695319150429552e-08 [ao]
# 	Er162          =	6.28379803610933e-19 [ao]
# 	Er164          =	3.6969077750418455e-13 [ao]
# 	Er166          =	3.4281895014965072e-09 [ao]
# 	Er167          =	9.588653044008082e-10 [ao]
# 	Er168          =	4.805795524634084e-10 [ao]
# 	Er170          =	7.767853798046619e-11 [ao]
# 	Eu151          =	2.7822585143965642e-05 [ao]
# 	Eu153          =	1.4811554980726098e-05 [ao]
# 	Eu155          =	7.606871627206396e-21 [ao]
# 	Eu156          =	7.932224899463347e-26 [ao]
# 	Eu157          =	4.698156989645602e-28 [ao]
# 	F19            =	1.0029715702004186e-21 [ao]
# 	Fe54           =	9.90175152764356e-22 [ao]
# 	Fe56           =	1.007649885742872e-21 [ao]
# 	Fe57           =	9.986350329853896e-22 [ao]
# 	Fe58           =	3.000329833715214e-21 [ao]
# 	Ga69           =	4.469960050157977e-10 [ao]
# 	Ga71           =	1.6984701509083118e-09 [ao]
# 	Gd152          =	1.4816710413257036e-07 [ao]
# 	Gd153          =	7.181263001258336e-24 [ao]
# 	Gd154          =	3.327813265299109e-06 [ao]
# 	Gd155          =	7.048015899165993e-06 [ao]
# 	Gd156          =	6.292777888963144e-06 [ao]
# 	Gd157          =	3.200573584061906e-06 [ao]
# 	Gd158          =	2.1386769030654017e-06 [ao]
# 	Gd160          =	4.1746523058439503e-07 [ao]
# 	Ge70           =	6.074028683354407e-12 [ao]
# 	Ge72           =	4.969744153849496e-09 [ao]
# 	Ge73           =	1.1065999838171799e-08 [ao]
# 	Ge74           =	2.6007809442644058e-08 [ao]
# 	Ge76           =	1.1709697631640168e-07 [ao]
# 	H1             =	2.9760746167446944e-07 [ao]
# 	H2             =	6.453092413237743e-12 [ao]
# 	He3            =	3.514306035312783e-18 [ao]
# 	He4            =	9.036015156797252e-08 [ao]
# 	Hf174          =	7.859304862397496e-22 [ao]
# 	Hf176          =	1.06788046919264e-21 [ao]
# 	Hf177          =	1.0860069756046572e-21 [ao]
# 	Hf178          =	1.2415811973042608e-21 [ao]
# 	Hf179          =	8.914491216335646e-22 [ao]
# 	Hf180          =	1.9613447910552962e-21 [ao]
# 	Hg196          =	9.900600157305297e-22 [ao]
# 	Hg198          =	1.0841401807794414e-21 [ao]
# 	Hg199          =	9.65825965284249e-22 [ao]
# 	Hg200          =	1.0467865769395672e-21 [ao]
# 	Hg201          =	9.829654850711742e-22 [ao]
# 	Hg202          =	1.034599356448278e-21 [ao]
# 	Hg204          =	9.92676048625833e-22 [ao]
# 	Ho165          =	5.241832003296103e-09 [ao]
# 	Ho166_m1       =	1.1128285008867876e-23 [ao]
# 	I127           =	1.8903800353003502e-05 [ao]
# 	I129           =	5.705122383906787e-05 [ao]
# 	I135           =	7.557553891234674e-26 [ao]
# 	In113          =	6.281411076110132e-08 [ao]
# 	In115          =	1.744034622217143e-06 [ao]
# 	Ir191          =	7.750460449841221e-22 [ao]
# 	Ir193          =	8.103485521078484e-22 [ao]
# 	K39            =	9.961734029300859e-22 [ao]
# 	K40            =	9.779109897885734e-22 [ao]
# 	K41            =	1.0006220869930424e-21 [ao]
# 	Kr78           =	2.0862246313006352e-20 [ao]
# 	Kr80           =	2.3525460674778634e-10 [ao]
# 	Kr82           =	2.228672122439182e-07 [ao]
# 	Kr83           =	1.3750626317180164e-05 [ao]
# 	Kr84           =	2.451615133090584e-05 [ao]
# 	Kr86           =	3.8231014339240136e-05 [ao]
# 	La138          =	1.5200288875748873e-08 [ao]
# 	La139          =	0.0002566096903571931 [ao]
# 	Li6            =	1.0026512962214673e-21 [ao]
# 	Li7            =	1.486823701695878e-21 [ao]
# 	Lu175          =	9.640656463078443e-22 [ao]
# 	Lu176          =	7.856356956772265e-22 [ao]
# 	Mg24           =	9.99461829592182e-22 [ao]
# 	Mg25           =	9.988436424674279e-22 [ao]
# 	Mg26           =	1.001107915682457e-21 [ao]
# 	Mn55           =	1.0004148065615219e-21 [ao]
# 	Mo100          =	0.000441456045078339 [ao]
# 	Mo92           =	0.00020650289990495116 [ao]
# 	Mo94           =	0.00012833626452335035 [ao]
# 	Mo95           =	0.0004428241722295675 [ao]
# 	Mo96           =	0.00025754142030826065 [ao]
# 	Mo97           =	0.00037329393921628257 [ao]
# 	Mo98           =	0.000620128125922428 [ao]
# 	Mo99           =	2.0729386198080097e-19 [ao]
# 	N14            =	1.0111317239323551e-21 [ao]
# 	N15            =	1.000004868152041e-21 [ao]
# 	Na23           =	9.999854949054073e-22 [ao]
# 	Nb93           =	7.89734142598651e-06 [ao]
# 	Nb94           =	6.707321556169929e-10 [ao]
# 	Nb95           =	3.275321544184744e-22 [ao]
# 	Nd142          =	2.679089225824157e-06 [ao]
# 	Nd143          =	0.00019750716817739682 [ao]
# 	Nd144          =	0.0001798674297455074 [ao]
# 	Nd145          =	0.0001373526292320933 [ao]
# 	Nd146          =	0.0001226508861722724 [ao]
# 	Nd147          =	9.302117199477995e-22 [ao]
# 	Nd148          =	7.66395780124496e-05 [ao]
# 	Nd150          =	4.526603543940052e-05 [ao]
# 	Ni58           =	9.858485985575014e-22 [ao]
# 	Ni59           =	6.105895195980773e-22 [ao]
# 	Ni60           =	1.806110978321229e-21 [ao]
# 	Ni61           =	8.410085479552441e-21 [ao]
# 	Ni62           =	2.336485956922184e-19 [ao]
# 	Ni64           =	2.7310106528407653e-14 [ao]
# 	Np236          =	1.5778984368784919e-09 [ao]
# 	Np237          =	0.00011225114198308835 [ao]
# 	Np239          =	4.536703943422435e-15 [ao]
# 	O16            =	1.0004070834261113e-21 [ao]
# 	O17            =	9.825908649923844e-22 [ao]
# 	P31            =	9.997739922291937e-22 [ao]
# 	Pa229          =	6.688570864279678e-29 [ao]
# 	Pa231          =	6.689579094262951e-08 [ao]
# 	Pa232          =	7.454209244220297e-20 [ao]
# 	Pa233          =	3.866670764072218e-12 [ao]
# 	Pb204          =	1.023919380786276e-21 [ao]
# 	Pb206          =	3.744231514653397e-07 [ao]
# 	Pb207          =	2.8888836950652128e-08 [ao]
# 	Pb208          =	5.6787872932566917e-11 [ao]
# 	Pd102          =	2.383025669452893e-09 [ao]
# 	Pd104          =	2.206699194510634e-05 [ao]
# 	Pd105          =	0.00022419104130081378 [ao]
# 	Pd106          =	0.00020857808276901737 [ao]
# 	Pd107          =	0.00012838487574702576 [ao]
# 	Pd108          =	0.00010475629287771218 [ao]
# 	Pd110          =	2.719927966714743e-05 [ao]
# 	Pm147          =	8.140847644379144e-20 [ao]
# 	Pm149          =	3.7038814533828266e-27 [ao]
# 	Pr141          =	0.00023720312838601776 [ao]
# 	Pr143          =	1.8794582163605383e-24 [ao]
# 	Pu236          =	3.97916519288884e-15 [ao]
# 	Pu237          =	7.629285881994764e-32 [ao]
# 	Pu239          =	0.0009744504914395785 [ao]
# 	Pu240          =	4.511126479814554e-06 [ao]
# 	Pu241          =	1.2120703327043413e-13 [ao]
# 	Pu242          =	7.659070012388015e-06 [ao]
# 	Pu243          =	1.2572238564514294e-22 [ao]
# 	Pu244          =	4.1530902854570277e-11 [ao]
# 	Pu246          =	3.8867540642870955e-28 [ao]
# 	Ra223          =	6.385049972094521e-14 [ao]
# 	Ra224          =	1.492996285255291e-17 [ao]
# 	Ra225          =	3.3470014544268624e-13 [ao]
# 	Ra226          =	3.310642264158204e-08 [ao]
# 	Rb85           =	2.633845633373412e-05 [ao]
# 	Rb87           =	4.958606052213883e-05 [ao]
# 	Re185          =	8.227814473392098e-22 [ao]
# 	Re187          =	8.466000138980597e-22 [ao]
# 	Rh103          =	0.00029408693866794105 [ao]
# 	Rh105          =	1.3743130385679238e-23 [ao]
# 	Ru100          =	2.5026231813013342e-05 [ao]
# 	Ru101          =	0.0002568127131550027 [ao]
# 	Ru102          =	0.0002968892367791958 [ao]
# 	Ru104          =	0.00026479129665180155 [ao]
# 	Ru105          =	1.763162907717796e-24 [ao]
# 	Ru96           =	4.017175531221594e-21 [ao]
# 	Ru98           =	1.081405127834941e-10 [ao]
# 	Ru99           =	4.058273887714665e-05 [ao]
# 	S32            =	9.939267952822206e-22 [ao]
# 	S33            =	9.317183112494287e-22 [ao]
# 	S34            =	9.9994814620324e-22 [ao]
# 	S36            =	9.99856927273344e-22 [ao]
# 	Sb121          =	1.613682780207037e-06 [ao]
# 	Sb123          =	1.92430250407159e-06 [ao]
# 	Sb126          =	1.4013840509910648e-13 [ao]
# 	Sc45           =	9.905875521865625e-22 [ao]
# 	Se74           =	3.252977478135843e-13 [ao]
# 	Se76           =	2.475427824026037e-09 [ao]
# 	Se77           =	2.8896885918800316e-07 [ao]
# 	Se78           =	8.030063454984878e-07 [ao]
# 	Se79           =	1.5988510565140937e-06 [ao]
# 	Se80           =	3.8784705163068584e-06 [ao]
# 	Se82           =	1.0054969601783017e-05 [ao]
# 	Si28           =	9.998268880988696e-22 [ao]
# 	Si29           =	1.0075177644627454e-21 [ao]
# 	Si30           =	1.074385849379034e-21 [ao]
# 	Sm144          =	1.0336742946989808e-20 [ao]
# 	Sm147          =	8.675367412598741e-05 [ao]
# 	Sm148          =	9.628497021004016e-06 [ao]
# 	Sm149          =	4.9394504236977396e-05 [ao]
# 	Sm150          =	1.008622001393383e-05 [ao]
# 	Sm151          =	7.088223325294289e-119 [ao]
# 	Sm152          =	3.1546583755957804e-05 [ao]
# 	Sm153          =	1.6443732494045564e-22 [ao]
# 	Sm154          =	1.1344089661994663e-05 [ao]
# 	Sn112          =	2.329381071827173e-13 [ao]
# 	Sn114          =	1.8019460881706693e-09 [ao]
# 	Sn115          =	8.985535109243106e-08 [ao]
# 	Sn116          =	1.5900538525023244e-07 [ao]
# 	Sn117          =	1.925276249536664e-06 [ao]
# 	Sn118          =	1.5981233611446602e-06 [ao]
# 	Sn119          =	1.50375991322148e-06 [ao]
# 	Sn120          =	1.4611919395681583e-06 [ao]
# 	Sn122          =	1.972107220071549e-06 [ao]
# 	Sn124          =	3.302541394914134e-06 [ao]
# 	Sn126          =	6.808952329509993e-06 [ao]
# 	Sr84           =	1.1892939697461675e-11 [ao]
# 	Sr86           =	5.985208779037779e-07 [ao]
# 	Sr87           =	1.3143614127847154e-08 [ao]
# 	Sr88           =	6.497867068652655e-05 [ao]
# 	Sr90           =	1.6949797341524355e-17 [ao]
# 	Ta181          =	1.0508923705008086e-21 [ao]
# 	Ta182          =	7.008390323636197e-45 [ao]
# 	Tb159          =	8.13318951764736e-07 [ao]
# 	Tc99           =	0.00022750387416766278 [ao]
# 	Te120          =	1.229711975396388e-15 [ao]
# 	Te122          =	8.310039086543119e-08 [ao]
# 	Te123          =	1.9523023547712252e-09 [ao]
# 	Te124          =	7.5907203424641e-08 [ao]
# 	Te125          =	4.352489798814279e-06 [ao]
# 	Te126          =	1.4431799493193117e-06 [ao]
# 	Te127_m1       =	1.365689964603233e-25 [ao]
# 	Te128          =	3.015795906455853e-05 [ao]
# 	Te130          =	0.0001034154236149177 [ao]
# 	Th227          =	1.0291075939115683e-13 [ao]
# 	Th228          =	2.8487591070520216e-15 [ao]
# 	Th229          =	6.022224157812738e-08 [ao]
# 	Th230          =	1.6150245407980466e-06 [ao]
# 	Th231          =	1.3019608091200912e-14 [ao]
# 	Th232          =	1.0741061181500317e-06 [ao]
# 	Th234          =	3.7776979430877353e-13 [ao]
# 	Ti46           =	1.005871616162602e-21 [ao]
# 	Ti47           =	9.954545592572596e-22 [ao]
# 	Ti48           =	1.0053837201506916e-21 [ao]
# 	Ti49           =	1.0013570446753559e-21 [ao]
# 	Ti50           =	1.0027932157364278e-21 [ao]
# 	Tl203          =	9.803732130747523e-22 [ao]
# 	Tl205          =	1.848687878605534e-21 [ao]
# 	Tm169          =	1.657987751199868e-10 [ao]
# 	U232           =	9.738954136701843e-14 [ao]
# 	U233           =	1.6279027219530945e-06 [ao]
# 	U234           =	1.3485705731214886e-05 [ao]
# 	U235           =	0.003147510780834131 [ao]
# 	U236           =	0.0008879516684523673 [ao]
# 	U237           =	3.840397454973853e-21 [ao]
# 	U238           =	0.025580717070351408 [ao]
# 	U240           =	8.226691047390706e-22 [ao]
# 	V50            =	9.953246519981695e-22 [ao]
# 	V51            =	1.009683689709559e-21 [ao]
# 	W180           =	1.0003208729797286e-21 [ao]
# 	W182           =	2.0289040411015117e-21 [ao]
# 	W183           =	1.0271304688631584e-21 [ao]
# 	W184           =	1.055312087890786e-21 [ao]
# 	W186           =	9.751107798824586e-22 [ao]
# 	Xe123          =	1.5690721411937677e-31 [ao]
# 	Xe124          =	1.8992016777832506e-18 [ao]
# 	Xe126          =	4.2101171760092847e-10 [ao]
# 	Xe128          =	1.2095228553709714e-06 [ao]
# 	Xe129          =	1.5509882708175063e-07 [ao]
# 	Xe130          =	2.7718920662582175e-06 [ao]
# 	Xe131          =	0.00016536350445432794 [ao]
# 	Xe132          =	0.0002460807346920085 [ao]
# 	Xe134          =	0.0003471745934879812 [ao]
# 	Xe135          =	1.0508629885855397e-25 [ao]
# 	Xe136          =	0.00031952736732979544 [ao]
# 	Y89            =	8.471047828762859e-05 [ao]
# 	Y90            =	4.294743961874418e-21 [ao]
# 	Y91            =	4.391052652245094e-19 [ao]
# 	Zn64           =	9.041660706239722e-19 [ao]
# 	Zn66           =	3.180840323561287e-11 [ao]
# 	Zn67           =	1.5169359577827155e-10 [ao]
# 	Zn68           =	2.413577717283344e-10 [ao]
# 	Zn70           =	1.0370800315902144e-09 [ao]
# 	Zr90           =	0.005564239684146962 [ao]
# 	Zr91           =	0.0013223897487811547 [ao]
# 	Zr92           =	0.0019667464007460476 [ao]
# 	Zr93           =	0.0001947598477790044 [ao]
# 	Zr94           =	0.0020357210992412414 [ao]
# 	Zr95           =	5.998042243098924e-22 [ao]
# 	Zr96           =	0.0005259172197730529 [ao]
